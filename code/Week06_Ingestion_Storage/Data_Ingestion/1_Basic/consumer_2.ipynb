# %%
# import required libraries
from kafka import KafkaConsumer

# %%
# Connect to kafka broker running in your local host (docker). Change this to your kafka broker if needed
kafka_broker = 'localhost:9092'

# %%
consumer = KafkaConsumer(
     bootstrap_servers=[kafka_broker],
     enable_auto_commit=True,
     value_deserializer=lambda x: x.decode('utf-8'))

# %%
consumer.subscribe('sample')

# %%
print('Running Consumer #2')
while(True):
    results = consumer.poll(timeout_ms=1000)
    if len(results) == 0:
        print('no message')
    else:
        for tp, messages in results.items():
            print('topic = {} -- total {} messages'.format(tp.topic, len(messages)))
            print('-----')
            for message in messages:
                print(message)
    print('######################')
# Out:
# Running Consumer #2
# topic = sample -- total 1 messages
# -----
# ConsumerRecord(topic='sample', partition=0, offset=37, timestamp=1731379654147, timestamp_type=0, key=None, value='message #27 from producer-0', headers=[], checksum=None, serialized_key_size=-1, serialized_value_size=27, serialized_header_size=-1)
# ######################
# topic = sample -- total 1 messages
# -----
# ConsumerRecord(topic='sample', partition=0, offset=38, timestamp=1731379654837, timestamp_type=0, key=None, value='message #10 from another producer', headers=[], checksum=None, serialized_key_size=-1, serialized_value_size=33, serialized_header_size=-1)
# ######################
# no message
# ######################
# topic = sample -- total 1 messages
# -----
# ConsumerRecord(topic='sample', partition=0, offset=39, timestamp=1731379656153, timestamp_type=0, key=None, value='message #28 from producer-0', headers=[], checksum=None, serialized_key_size=-1, serialized_value_size=27, serialized_header_size=-1)
# ######################
# no message
# ######################
# topic = sample -- total 1 messages
# -----
# ConsumerRecord(topic='sample', partition=0, offset=40, timestamp=1731379657843, timestamp_type=0, key=None, value='message #11 from another producer', headers=[], checksum=None, serialized_key_size=-1, serialized_value_size=33, serialized_header_size=-1)
# ######################
# topic = sample -- total 1 messages
# -----
# ConsumerRecord(topic='sample', partition=0, offset=41, timestamp=1731379658157, timestamp_type=0, key=None, value='message #29 from producer-0', headers=[], checksum=None, serialized_key_size=-1, serialized_value_size=27, serialized_header_size=-1)
# ######################
# no message
# ######################
# no message
# ######################
# topic = sample -- total 1 messages
# -----
# ConsumerRecord(topic='sample', partition=0, offset=42, timestamp=1731379660159, timestamp_type=0, key=None, value='message #30 from producer-0', headers=[], checksum=None, serialized_key_size=-1, serialized_value_size=27, serialized_header_size=-1)
# ######################
# topic = sample -- total 1 messages
# -----
# ConsumerRecord(topic='sample', partition=0, offset=43, timestamp=1731379660849, timestamp_type=0, key=None, value='message #12 from another producer', headers=[], checksum=None, serialized_key_size=-1, serialized_value_size=33, serialized_header_size=-1)
# ######################
# no message
# ######################
# topic = sample -- total 1 messages
# -----
# ConsumerRecord(topic='sample', partition=0, offset=44, timestamp=1731379662164, timestamp_type=0, key=None, value='message #31 from producer-0', headers=[], checksum=None, serialized_key_size=-1, serialized_value_size=27, serialized_header_size=-1)
# ######################
# no message
# ######################
# topic = sample -- total 1 messages
# -----
# ConsumerRecord(topic='sample', partition=0, offset=45, timestamp=1731379663855, timestamp_type=0, key=None, value='message #13 from another producer', headers=[], checksum=None, serialized_key_size=-1, serialized_value_size=33, serialized_header_size=-1)
# ######################
# topic = sample -- total 1 messages
# -----
# ConsumerRecord(topic='sample', partition=0, offset=46, timestamp=1731379664170, timestamp_type=0, key=None, value='message #32 from producer-0', headers=[], checksum=None, serialized_key_size=-1, serialized_value_size=27, serialized_header_size=-1)
# ######################
# no message
# ######################
# no message
# ######################
# topic = sample -- total 1 messages
# -----
# ConsumerRecord(topic='sample', partition=0, offset=47, timestamp=1731379666176, timestamp_type=0, key=None, value='message #33 from producer-0', headers=[], checksum=None, serialized_key_size=-1, serialized_value_size=27, serialized_header_size=-1)
# ######################
# topic = sample -- total 1 messages
# -----
# ConsumerRecord(topic='sample', partition=0, offset=48, timestamp=1731379666861, timestamp_type=0, key=None, value='message #14 from another producer', headers=[], checksum=None, serialized_key_size=-1, serialized_value_size=33, serialized_header_size=-1)
# ######################
# no message
# ######################
# topic = sample -- total 1 messages
# -----
# ConsumerRecord(topic='sample', partition=0, offset=49, timestamp=1731379668180, timestamp_type=0, key=None, value='message #34 from producer-0', headers=[], checksum=None, serialized_key_size=-1, serialized_value_size=27, serialized_header_size=-1)
# ######################
# no message
# ######################
# topic = sample -- total 1 messages
# -----
# ConsumerRecord(topic='sample', partition=0, offset=50, timestamp=1731379669864, timestamp_type=0, key=None, value='message #15 from another producer', headers=[], checksum=None, serialized_key_size=-1, serialized_value_size=33, serialized_header_size=-1)
# ######################
# topic = sample -- total 1 messages
# -----
# ConsumerRecord(topic='sample', partition=0, offset=51, timestamp=1731379670184, timestamp_type=0, key=None, value='message #35 from producer-0', headers=[], checksum=None, serialized_key_size=-1, serialized_value_size=27, serialized_header_size=-1)
# ######################
# no message
# ######################
# no message
# ######################
# topic = sample -- total 1 messages
# -----
# ConsumerRecord(topic='sample', partition=0, offset=52, timestamp=1731379672191, timestamp_type=0, key=None, value='message #36 from producer-0', headers=[], checksum=None, serialized_key_size=-1, serialized_value_size=27, serialized_header_size=-1)
# ######################
# topic = sample -- total 1 messages
# -----
# ConsumerRecord(topic='sample', partition=0, offset=53, timestamp=1731379672876, timestamp_type=0, key=None, value='message #16 from another producer', headers=[], checksum=None, serialized_key_size=-1, serialized_value_size=33, serialized_header_size=-1)
# ######################
# no message
# ######################
# topic = sample -- total 1 messages
# -----
# ConsumerRecord(topic='sample', partition=0, offset=54, timestamp=1731379674196, timestamp_type=0, key=None, value='message #37 from producer-0', headers=[], checksum=None, serialized_key_size=-1, serialized_value_size=27, serialized_header_size=-1)
# ######################
# no message
# ######################
# topic = sample -- total 1 messages
# -----
# ConsumerRecord(topic='sample', partition=0, offset=55, timestamp=1731379675881, timestamp_type=0, key=None, value='message #17 from another producer', headers=[], checksum=None, serialized_key_size=-1, serialized_value_size=33, serialized_header_size=-1)
# ######################
# topic = sample -- total 1 messages
# -----
# ConsumerRecord(topic='sample', partition=0, offset=56, timestamp=1731379676202, timestamp_type=0, key=None, value='message #38 from producer-0', headers=[], checksum=None, serialized_key_size=-1, serialized_value_size=27, serialized_header_size=-1)
# ######################
# no message
# ######################
# no message
# ######################
# topic = sample -- total 1 messages
# -----
# ConsumerRecord(topic='sample', partition=0, offset=57, timestamp=1731379678206, timestamp_type=0, key=None, value='message #39 from producer-0', headers=[], checksum=None, serialized_key_size=-1, serialized_value_size=27, serialized_header_size=-1)
# ######################
# topic = sample -- total 1 messages
# -----
# ConsumerRecord(topic='sample', partition=0, offset=58, timestamp=1731379678884, timestamp_type=0, key=None, value='message #18 from another producer', headers=[], checksum=None, serialized_key_size=-1, serialized_value_size=33, serialized_header_size=-1)
# ######################
# no message
# ######################
# topic = sample -- total 1 messages
# -----
# ConsumerRecord(topic='sample', partition=0, offset=59, timestamp=1731379680213, timestamp_type=0, key=None, value='message #40 from producer-0', headers=[], checksum=None, serialized_key_size=-1, serialized_value_size=27, serialized_header_size=-1)
# ######################
# no message
# ######################
# topic = sample -- total 1 messages
# -----
# ConsumerRecord(topic='sample', partition=0, offset=60, timestamp=1731379681890, timestamp_type=0, key=None, value='message #19 from another producer', headers=[], checksum=None, serialized_key_size=-1, serialized_value_size=33, serialized_header_size=-1)
# ######################
# topic = sample -- total 1 messages
# -----
# ConsumerRecord(topic='sample', partition=0, offset=61, timestamp=1731379682218, timestamp_type=0, key=None, value='message #41 from producer-0', headers=[], checksum=None, serialized_key_size=-1, serialized_value_size=27, serialized_header_size=-1)
# ######################
# no message
# ######################
# topic = sample -- total 1 messages
# -----
# ConsumerRecord(topic='sample', partition=0, offset=62, timestamp=1731379684220, timestamp_type=0, key=None, value='message #42 from producer-0', headers=[], checksum=None, serialized_key_size=-1, serialized_value_size=27, serialized_header_size=-1)
# ######################
# topic = sample -- total 1 messages
# -----
# ConsumerRecord(topic='sample', partition=0, offset=63, timestamp=1731379684895, timestamp_type=0, key=None, value='message #20 from another producer', headers=[], checksum=None, serialized_key_size=-1, serialized_value_size=33, serialized_header_size=-1)
# ######################
# no message
# ######################
# topic = sample -- total 1 messages
# -----
# ConsumerRecord(topic='sample', partition=0, offset=64, timestamp=1731379686224, timestamp_type=0, key=None, value='message #43 from producer-0', headers=[], checksum=None, serialized_key_size=-1, serialized_value_size=27, serialized_header_size=-1)
# ######################
# no message
# ######################
# topic = sample -- total 1 messages
# -----
# ConsumerRecord(topic='sample', partition=0, offset=65, timestamp=1731379687900, timestamp_type=0, key=None, value='message #21 from another producer', headers=[], checksum=None, serialized_key_size=-1, serialized_value_size=33, serialized_header_size=-1)
# ######################
# topic = sample -- total 1 messages
# -----
# ConsumerRecord(topic='sample', partition=0, offset=66, timestamp=1731379688225, timestamp_type=0, key=None, value='message #44 from producer-0', headers=[], checksum=None, serialized_key_size=-1, serialized_value_size=27, serialized_header_size=-1)
# ######################
# no message
# ######################
# no message
# ######################
# topic = sample -- total 1 messages
# -----
# ConsumerRecord(topic='sample', partition=0, offset=67, timestamp=1731379690228, timestamp_type=0, key=None, value='message #45 from producer-0', headers=[], checksum=None, serialized_key_size=-1, serialized_value_size=27, serialized_header_size=-1)
# ######################
# topic = sample -- total 1 messages
# -----
# ConsumerRecord(topic='sample', partition=0, offset=68, timestamp=1731379690905, timestamp_type=0, key=None, value='message #22 from another producer', headers=[], checksum=None, serialized_key_size=-1, serialized_value_size=33, serialized_header_size=-1)
# ######################
# no message
# ######################
# topic = sample -- total 1 messages
# -----
# ConsumerRecord(topic='sample', partition=0, offset=69, timestamp=1731379692235, timestamp_type=0, key=None, value='message #46 from producer-0', headers=[], checksum=None, serialized_key_size=-1, serialized_value_size=27, serialized_header_size=-1)
# ######################
# no message
# ######################
# topic = sample -- total 1 messages
# -----
# ConsumerRecord(topic='sample', partition=0, offset=70, timestamp=1731379693908, timestamp_type=0, key=None, value='message #23 from another producer', headers=[], checksum=None, serialized_key_size=-1, serialized_value_size=33, serialized_header_size=-1)
# ######################
# topic = sample -- total 1 messages
# -----
# ConsumerRecord(topic='sample', partition=0, offset=71, timestamp=1731379694240, timestamp_type=0, key=None, value='message #47 from producer-0', headers=[], checksum=None, serialized_key_size=-1, serialized_value_size=27, serialized_header_size=-1)
# ######################
# no message
# ######################
# no message
# ######################
# topic = sample -- total 1 messages
# -----
# ConsumerRecord(topic='sample', partition=0, offset=72, timestamp=1731379696245, timestamp_type=0, key=None, value='message #48 from producer-0', headers=[], checksum=None, serialized_key_size=-1, serialized_value_size=27, serialized_header_size=-1)
# ######################
# topic = sample -- total 1 messages
# -----
# ConsumerRecord(topic='sample', partition=0, offset=73, timestamp=1731379696911, timestamp_type=0, key=None, value='message #24 from another producer', headers=[], checksum=None, serialized_key_size=-1, serialized_value_size=33, serialized_header_size=-1)
# ######################
# no message
# ######################
# topic = sample -- total 1 messages
# -----
# ConsumerRecord(topic='sample', partition=0, offset=74, timestamp=1731379698246, timestamp_type=0, key=None, value='message #49 from producer-0', headers=[], checksum=None, serialized_key_size=-1, serialized_value_size=27, serialized_header_size=-1)
# ######################
# no message
# ######################
# topic = sample -- total 1 messages
# -----
# ConsumerRecord(topic='sample', partition=0, offset=75, timestamp=1731379699912, timestamp_type=0, key=None, value='message #25 from another producer', headers=[], checksum=None, serialized_key_size=-1, serialized_value_size=33, serialized_header_size=-1)
# ######################
# topic = sample -- total 1 messages
# -----
# ConsumerRecord(topic='sample', partition=0, offset=76, timestamp=1731379700255, timestamp_type=0, key=None, value='message #50 from producer-0', headers=[], checksum=None, serialized_key_size=-1, serialized_value_size=27, serialized_header_size=-1)
# ######################
# no message
# ######################
# topic = sample -- total 1 messages
# -----
# ConsumerRecord(topic='sample', partition=0, offset=77, timestamp=1731379702264, timestamp_type=0, key=None, value='message #51 from producer-0', headers=[], checksum=None, serialized_key_size=-1, serialized_value_size=27, serialized_header_size=-1)
# ######################
# topic = sample -- total 1 messages
# -----
# ConsumerRecord(topic='sample', partition=0, offset=78, timestamp=1731379702916, timestamp_type=0, key=None, value='message #26 from another producer', headers=[], checksum=None, serialized_key_size=-1, serialized_value_size=33, serialized_header_size=-1)
# ######################
# no message
# ######################
# topic = sample -- total 1 messages
# -----
# ConsumerRecord(topic='sample', partition=0, offset=79, timestamp=1731379704268, timestamp_type=0, key=None, value='message #52 from producer-0', headers=[], checksum=None, serialized_key_size=-1, serialized_value_size=27, serialized_header_size=-1)
# ######################
# no message
# ######################
# topic = sample -- total 1 messages
# -----
# ConsumerRecord(topic='sample', partition=0, offset=80, timestamp=1731379705920, timestamp_type=0, key=None, value='message #27 from another producer', headers=[], checksum=None, serialized_key_size=-1, serialized_value_size=33, serialized_header_size=-1)
# ######################
# topic = sample -- total 1 messages
# -----
# ConsumerRecord(topic='sample', partition=0, offset=81, timestamp=1731379706269, timestamp_type=0, key=None, value='message #53 from producer-0', headers=[], checksum=None, serialized_key_size=-1, serialized_value_size=27, serialized_header_size=-1)
# ######################
# no message
# ######################
# no message
# ######################
# topic = sample -- total 1 messages
# -----
# ConsumerRecord(topic='sample', partition=0, offset=82, timestamp=1731379708274, timestamp_type=0, key=None, value='message #54 from producer-0', headers=[], checksum=None, serialized_key_size=-1, serialized_value_size=27, serialized_header_size=-1)
# ######################
# topic = sample -- total 1 messages
# -----
# ConsumerRecord(topic='sample', partition=0, offset=83, timestamp=1731379708921, timestamp_type=0, key=None, value='message #28 from another producer', headers=[], checksum=None, serialized_key_size=-1, serialized_value_size=33, serialized_header_size=-1)
# ######################
# no message
# ######################
# topic = sample -- total 1 messages
# -----
# ConsumerRecord(topic='sample', partition=0, offset=84, timestamp=1731379710280, timestamp_type=0, key=None, value='message #55 from producer-0', headers=[], checksum=None, serialized_key_size=-1, serialized_value_size=27, serialized_header_size=-1)
# ######################
# no message
# ######################
# topic = sample -- total 1 messages
# -----
# ConsumerRecord(topic='sample', partition=0, offset=85, timestamp=1731379711927, timestamp_type=0, key=None, value='message #29 from another producer', headers=[], checksum=None, serialized_key_size=-1, serialized_value_size=33, serialized_header_size=-1)
# ######################
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[5], line 3
#       1 print('Running Consumer #2')
#       2 while(True):
# ----> 3     results = consumer.poll(timeout_ms=1000)
#       4     if len(results) == 0:
#       5         print('no message')
#
# File ~/anaconda3/lib/python3.11/site-packages/kafka/consumer/group.py:655, in KafkaConsumer.poll(self, timeout_ms, max_records, update_offsets)
#     653 remaining = timeout_ms
#     654 while True:
# --> 655     records = self._poll_once(remaining, max_records, update_offsets=update_offsets)
#     656     if records:
#     657         return records
#
# File ~/anaconda3/lib/python3.11/site-packages/kafka/consumer/group.py:702, in KafkaConsumer._poll_once(self, timeout_ms, max_records, update_offsets)
#     699     self._client.poll(timeout_ms=0)
#     701 timeout_ms = min(timeout_ms, self._coordinator.time_to_next_poll() * 1000)
# --> 702 self._client.poll(timeout_ms=timeout_ms)
#     703 # after the long poll, we should check whether the group needs to rebalance
#     704 # prior to returning data so that the group can stabilize faster
#     705 if self._coordinator.need_rejoin():
#
# File ~/anaconda3/lib/python3.11/site-packages/kafka/client_async.py:602, in KafkaClient.poll(self, timeout_ms, future)
#     599             timeout = min(timeout, self.config['retry_backoff_ms'])
#     600         timeout = max(0, timeout)  # avoid negative timeouts
# --> 602     self._poll(timeout / 1000)
#     604 # called without the lock to avoid deadlock potential
#     605 # if handlers need to acquire locks
#     606 responses.extend(self._fire_pending_completed_requests())
#
# File ~/anaconda3/lib/python3.11/site-packages/kafka/client_async.py:634, in KafkaClient._poll(self, timeout)
#     631 self._register_send_sockets()
#     633 start_select = time.time()
# --> 634 ready = self._selector.select(timeout)
#     635 end_select = time.time()
#     636 if self._sensors:
#
# File ~/anaconda3/lib/python3.11/selectors.py:561, in KqueueSelector.select(self, timeout)
#     559 ready = []
#     560 try:
# --> 561     kev_list = self._selector.control(None, max_ev, timeout)
#     562 except InterruptedError:
#     563     return ready
#
# KeyboardInterrupt:
